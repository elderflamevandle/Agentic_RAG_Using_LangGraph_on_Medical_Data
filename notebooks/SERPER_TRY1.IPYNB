# %%
import os
from dotenv import load_dotenv
from langchain_community.utilities import GoogleSerperAPIWrapper

load_dotenv(".env", override=True)  # or ".env" if that’s your file name/location
if not os.getenv("SERPER_API_KEY"):
    raise RuntimeError("Missing SERPER_API_KEY. Put it in .env as: SERPER_API_KEY=...")

# %%
search = GoogleSerperAPIWrapper()
print(search.run("What are the various vaccines of COVID-19?"))
# Out:
# The 2025-2026 COVID-19 vaccines available in the United States include Moderna, Pfizer-BioNTech and Novavax. The vaccines are all approved for people age 65 and ... Two types of COVID-19 vaccines are recommended for use in the United States: mRNA vaccines (Moderna and Pfizer-BioNTech) and a protein subunit ... First introduced in December 2020, the original COVID mRNA vaccines from both Pfizer and Moderna protected against the original SARS-CoV-2 virus ... 12 Vaccines Granted Emergency Use Listing (EUL) by WHO. Novavax. Nuvaxovid. Approved in 40 countries. 22 trials in 14 countries. On this page, you will find infographics to explain how different types of vaccines work, including the Pfizer/BioNTech vaccine, the Moderna vaccine and the ... WHO recommends a simplified single-dose regime for primary immunization for most COVID-19 vaccines which would improve acceptance and uptake and provide ... List of COVID-19 vaccine authorizations · Contents · Overview maps · Oxford–AstraZeneca · Pfizer–BioNTech · Janssen · Moderna · Sinopharm BIBP · Sputnik V. Explore data on COVID-19 vaccinations across the world. The COVID-19 VIS may be used when administering fully licensed vaccine (mRNA vaccine to people 12 years and older). For links to the current EUA ... Schedule your second dose of the COVID-19 vaccine at CVS Pharmacy. Moderna, Pfizer-BioNTech and Novavax vaccines are available. No cost with most insurance.
